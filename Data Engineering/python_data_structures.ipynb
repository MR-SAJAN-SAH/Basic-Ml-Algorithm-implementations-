# %%
arr = [1, 2, 3]
arr.append(4)
arr[0]        # 1
# Out:
# 1

# %%
point = (3, 4)

# %%
s = {1, 2, 3}
s.add(4)

# %%
d = {"a": 1, "b": 2}
d["c"] = 3

# %%
from collections import deque

q = deque([1, 2, 3])
q.appendleft(0)
q.pop()
print(q)
# Out:
# deque([0, 1, 2])

# %%
from collections import Counter

Counter("aabbbc")
# Out:
# Counter({'b': 3, 'a': 2, 'c': 1})

# %%
from collections import defaultdict

d = defaultdict(list)
d["a"].append(1)
